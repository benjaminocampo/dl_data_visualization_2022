# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %%
url = 'https://www.famaf.unc.edu.ar/~nocampo043/sysarmy_survey_2020_processed.csv'
df = pd.read_csv(url)

# %%
fig = plt.figure(figsize=(10,8))
seaborn.scatterplot(data=df, x="salary_monthly_NET", y="salary_monthly_GROSS", hue="work_contract_type")
# Out:
# <AxesSubplot:xlabel='salary_monthly_NET', ylabel='salary_monthly_GROSS'>
